# %% [markdown]
# ### 0. Introduction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/KUBIG/24_1_Advancedstudy_DA/Data/NLP/'

# %%
import base64
import numpy as np
import pandas as pd

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

from collections import Counter
from imageio import imread
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from matplotlib import pyplot as plt
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
train = pd.read_csv(data_path+'train.csv')

# %%
train.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
train.shape
# Out:
# (19579, 3)

# %% [markdown]
# ### 1. The Authors and their works EDA

# %%
train.author.unique()
# Out:
# array(['EAP', 'HPL', 'MWS'], dtype=object)

# %%
z = {'EAP': 'Edgar Allen Poe',
     'MWS': 'Mary Shelley',
     'HPL': 'HP Lovecraft'}

plt.bar(train.author.map(z).unique(), train.author.value_counts().values)
plt.title('Target variable distribution')
plt.xlabel('Author')
plt.ylabel('Number of Text Entries')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - go 패키지가 전부터 실행이 안돼서 그냥 matplotlib으로 실행

# %%
all_words = train['text'].str.split(expand=True).unstack().value_counts()
plt.figure(figsize=(12,7))
plt.bar(all_words.index.values[2:50], all_words.values[2:50])
plt.title('Top 50 (Uncleaned) Word frequencies in the training dataset')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - 문장 안에서 자주 구사되는 접속사, 주어, 전치사가 대부분
# - 작가의 주제나 컨셉에 대해 전혀 보여주지 않음

# %%
eap = train[train.author=='EAP']['text'].values
hpl = train[train.author=='HPL']['text'].values
mws = train[train.author=='MWS']['text'].values

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# - 단순한 wordcloud는 지겨우니 작가들의 대표작을 이미지로 선택해 만들어보자!

# %% [markdown]
# #### 이미지 인코딩

# %%
eap_64 = b'...'

# %%
hpl_64 = b'...'

# %%
mws_64 = b'...'

# %% [markdown]
# #### WordCloud

# %%
import codecs
f1 = open('eap.png', 'wb')
f1.write(codecs.decode(eap_64, 'base64'))
f1.close()
img1 = imread('eap.png')
hcmask = img1

f2 = open('mws.png', 'wb')
f2.write(codecs.decode(mws_64, 'base64'))
f2.close()
img2 = imread('mws.png')
hcmask2 = img2

f3 = open('hpl.png', 'wb')
f3.write(codecs.decode(hpl_64, 'base64'))
f3.close()
img3 = imread('hpl.png')
hcmask3 = img3
# Out:
# <ipython-input-15-9999bfdfa026>:5: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# <ipython-input-15-9999bfdfa026>:11: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# <ipython-input-15-9999bfdfa026>:17: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='black', max_words=10000, mask=hcmask, stopwords=STOPWORDS, max_font_size=40)
wc.generate(" ".join(eap))
plt.title('Edgar Allen Poe (The Raven)', fontsize=20)
plt.imshow(wc.recolor(colormap='PuBu', random_state=17), alpha=0.9)
plt.axis('off')
# Out:
# (-0.5, 639.5, 390.5, -0.5)

# %%
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='black', max_words=10000, mask=hcmask2, stopwords=STOPWORDS, max_font_size=40)
wc.generate(" ".join(mws))
plt.title("Mary Shelley (Frankenstein's Monster)", fontsize=18)
plt.imshow(wc.recolor(colormap='viridis', random_state=17), alpha=0.98)
plt.axis('off')
# Out:
# (-0.5, 639.5, 589.5, -0.5)

# %%
plt.figure(figsize=(10,10))
wc = WordCloud(background_color='black', max_words=10000, mask=hcmask3, stopwords=STOPWORDS, max_font_size=40)
wc.generate(" ".join(hpl))
plt.title('HP Lovecraft (Cthulhu-Squidy)', fontsize=20)
plt.imshow(wc.recolor(colormap='Pastel2', random_state=17), alpha=0.98)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ### 2. Natural Language Processing

# %% [markdown]
# #### Tokenization

# %%
import nltk

# %%
train.head(1)
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP

# %%
first_text = train.text.values[0]
print(first_text)
print("="*90)
print(first_text.split(" "))
# Out:
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# ...
# ['This', 'process,', 'however,', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon;', 'as', 'I', 'might', 'make', 'its', 'circuit,', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out,', 'without', 'being', 'aware', 'of', 'the', 'fact;', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall.']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
first_text_list = nltk.word_tokenize(first_text)   # tokenization
print(first_text_list)
# Out:
# ['This', 'process', ',', 'however', ',', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon', ';', 'as', 'I', 'might', 'make', 'its', 'circuit', ',', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out', ',', 'without', 'being', 'aware', 'of', 'the', 'fact', ';', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall', '.']

# %% [markdown]
# #### Stopword Removal

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
# Out:
# 179

# %% [markdown]
# - Let's remove Stopwords

# %%
first_text_list_cleaned = [word for word in first_text_list if word.lower() not in stopwords]  # filter out stopwords

print(first_text_list_cleaned)
print("="*90)
print(f"Length of original list: {len(first_text_list)} words")
print(f"Length of list after stopwords removal: {len(first_text_list_cleaned)} words")
# Out:
# ['process', ',', 'however', ',', 'afforded', 'means', 'ascertaining', 'dimensions', 'dungeon', ';', 'might', 'make', 'circuit', ',', 'return', 'point', 'whence', 'set', ',', 'without', 'aware', 'fact', ';', 'perfectly', 'uniform', 'seemed', 'wall', '.']
# ...
# Length of original list: 48 words
# Length of list after stopwords removal: 28 words

# %% [markdown]
# #### Stemming and Lemmatization

# %%
stemmer = nltk.stem.PorterStemmer()

# %%
print("The stemmed form of running is: {}".format(stemmer.stem("running")))
print("The stemmed form of runs is: {}".format(stemmer.stem("runs")))
print("The stemmed form of run is: {}".format(stemmer.stem("run")))
# Out:
# The stemmed form of running is: run
# The stemmed form of runs is: run
# The stemmed form of run is: run

# %% [markdown]
# - stemming: 어근 추출

# %%
print("The stemmed form of leaves is: {}".format(stemmer.stem("leaves")))
# Out:
# The stemmed form of leaves is: leav

# %% [markdown]
# - 어근 잘못 추출됨 -> 이럴 땐 stemming이 아닌 lemmatization!
#
#
# - Lemmatization이란? 실제 단어에 기반해 stemming하는 것, 즉 단어를 무작정 자르는게 아니라 실제 vocabulary에 기반해 어근을 추출함
# - 속도가 느리다는 한계!

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
print("The lemmatized form of leaves is: {}".format(lemm.lemmatize('leaves')))
# Out:
# The lemmatized form of leaves is: leaf

# %% [markdown]
# - Stemming과 다르게 잘 추출함

# %% [markdown]
# #### Vectorization

# %% [markdown]
# - The bag of words approach

# %%
sentence = ['I love to eat Burgers',
            'I love to eat Fries']
vectorizer = CountVectorizer(min_df=0)
sentence_transform = vectorizer.fit_transform(sentence)

# %%
print("The features are: \n {}".format(vectorizer.get_feature_names_out()))
print("\nThe vectorized array looks like: \n {}".format(sentence_transform.toarray()))
# Out:
# The features are:
#  ['burgers' 'eat' 'fries' 'love' 'to']
#
# The vectorized array looks like:
#  [[1 1 0 1 1]
#  [0 1 1 1 1]]

# %% [markdown]
# - 이렇게 겹치는 단어들(love,to) 같은 것들을 하나로 하여 vector화 시키고 이에 대한 one-hot encoding을 하는 것!

# %%
sentence_transform
# Out:
# <2x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 3. Topic modelling

# %%
def print_top_words(model, feature_names, n_top_words):
  for index, topic in enumerate(model.components_):
    message = "\nTopic #{}:".format(index)
    message += " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words-1:-1]])
    print(message)
    print("="*70)

# %% [markdown]
# - topic.argsort()[:-n_top_words-1:-1]: 중요도 상위 n_top_words 개의 인덱스 반환

# %%
lemm = WordNetLemmatizer()
class LemmaCountVectorizer(CountVectorizer):
  def build_analyzer(self):
    analyzer = super(LemmaCountVectorizer, self).build_analyzer()
    return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))

# %%
text = list(train.text.values)
tf_vectorizer = LemmaCountVectorizer(max_df=0.95,
                                     min_df=2,
                                     stop_words='english',
                                     decode_error='ignore')
tf = tf_vectorizer.fit_transform(text)

# %%
feature_names = list(tf_vectorizer.vocabulary_.keys())
count_vec = np.asarray(tf.sum(axis=0)).ravel()
zipped = list(zip(feature_names, count_vec))    # 각 feature들에 대해 vector 개수 계산

x, y = (list(x) for x in zip(*sorted(zipped, key=lambda x: x[1], reverse=True)))

Y = np.concatenate([y[:15], y[-16:-1]])    # top 15 words and bottom 15 words
X = np.concatenate([x[:15], x[-16:-1]])    # top 15 words and bottom 15 words

plt.figure(figsize=(12,7))
plt.bar(x[:50],y[:50])
plt.title("Top 50 word frequencies after preprocessing")
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.bar(x[-100:],y[-100:])
plt.title("Bottom 100 word frequencies after preprocessing")
plt.xticks(rotation=90)
plt.show()

# %%
lda = LatentDirichletAllocation(n_components=11, max_iter=5,
                                learning_method='online', learning_offset=50,
                                random_state=0)

# %%
lda.fit(tf)
# Out:
# LatentDirichletAllocation(learning_method='online', learning_offset=50,
#                           max_iter=5, n_components=11, random_state=0)

# %%
n_top_words = 40
print("\nTopics in LDA model: ")
tf_feature_names = list(tf_vectorizer.vocabulary_.keys())
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0:titan adieu managed unemployed wither barred considerably tempora gravitation jehovah gulf sire wed darling arabic shanty fenner unique stride upward willingly requires judgment lalande ember delicacy breach confusion recognised realization luxuriantly smiling adopting overspread gentle distinction squeezed excite ah folding
# ...
#
# Topic #1:hammer ainsworth finer fearlessly gaspingly legal dreadful ry majestically worshipped mynheer circular strangled renounce painstaking admission sprung pervading dilated implored winking chivalrous cunningly lafitte classic arve patriarch slid blade pillar fraud villain latitude saratoga towered revolution uncouth range building floundering
# ...
#
# ...

# %%
first_topic = lda.components_[0]
second_topic = lda.components_[1]
third_topic = lda.components_[2]
fourth_topic = lda.components_[3]

# %%
first_topic.shape
# Out:
# (13781,)

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50 - 1 :-1]]   # 마지막 50개 추출
second_topic_words = [tf_feature_names[i] for i in second_topic.argsort()[:-50 - 1 :-1]]
third_topic_words = [tf_feature_names[i] for i in third_topic.argsort()[:-50 - 1 :-1]]
fourth_topic_words = [tf_feature_names[i] for i in fourth_topic.argsort()[:-50 - 1 :-1]]

# %%
firstcloud = WordCloud(
    stopwords=STOPWORDS,
    background_color='black',
    width=2500,
    height=1800,
).generate(" ".join(first_topic_words))

plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
secoundcloud = WordCloud(
    stopwords=STOPWORDS,
    background_color='black',
    width=2500,
    height=1800,
).generate(" ".join(second_topic_words))

plt.imshow(secoundcloud)
plt.axis('off')
plt.show()

# %%
thirdcloud = WordCloud(
    stopwords=STOPWORDS,
    background_color='black',
    width=2500,
    height=1800,
).generate(" ".join(third_topic_words))

plt.imshow(thirdcloud)
plt.axis('off')
plt.show()

# %%
fourthcloud = WordCloud(
    stopwords=STOPWORDS,
    background_color='black',
    width=2500,
    height=1800,
).generate(" ".join(fourth_topic_words))

plt.imshow(fourthcloud)
plt.axis('off')
plt.show()
